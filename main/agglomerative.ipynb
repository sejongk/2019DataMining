# %%
import pandas as pd 

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix\

from sklearn.cluster import KMeans

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %%
X_train = pd.read_csv('bi_3_10000_X.csv', delimiter = ',')
Y_train = pd.read_csv('bi_3_10000_Y.csv', delimiter = ',')

# %%
X_train.shape, Y_train.shape
# Out:
# ((10000, 49), (10000, 2))

# %%
X_train = X_train.iloc[:,1:]
Y_train = Y_train.iloc[:,1]
Y_train = pd.factorize(Y_train)[0]

# %%
X_train = StandardScaler().fit_transform(X_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
X_train.shape, Y_train.shape
# Out:
# ((11000, 48), (11000,))

# %% [markdown]
# # 병합 군집

# %%
from sklearn.cluster import AgglomerativeClustering
link = ['ward','complete','average','single']

# %%
#bi_1 scale O
for j in link:
    agg = AgglomerativeClustering(n_clusters=2, linkage =j)
    result = agg.fit_predict(X_train)
    print("병합 군집의 클러스터 크기:",
       np.bincount(result))
    print(printSilhouette(X_train, result))
# Out:
# 병합 군집의 클러스터 크기: [1202 8798]
# 0.5321424953100005
# 병합 군집의 클러스터 크기: [9990   10]
# 0.8412238572867508
# 병합 군집의 클러스터 크기: [9999    1]
# 0.8627551386383475
# 병합 군집의 클러스터 크기: [9999    1]
# 0.8627551386383475

# %%
#bi_2
for j in link:
    agg = AgglomerativeClustering(n_clusters=2, linkage =j)
    result = agg.fit_predict(X_train)
    print("병합 군집의 클러스터 크기:",
       np.bincount(result))
    print(printSilhouette(X_train, result))
# Out:
# 병합 군집의 클러스터 크기: [9482  518]
# 0.6725443715437909
# 병합 군집의 클러스터 크기: [9988   12]
# 0.8594597754068769
# 병합 군집의 클러스터 크기: [9989   11]
# 0.8606680992894211
# 병합 군집의 클러스터 크기: [9998    2]
# 0.8750843900342157

# %%
#bi_3 scale O
for j in link:
    agg = AgglomerativeClustering(n_clusters=2, linkage =j)
    result = agg.fit_predict(X_train)
    print("병합 군집의 클러스터 크기:",
       np.bincount(result))
    print(printSilhouette(X_train, result))
# Out:
# 병합 군집의 클러스터 크기: [3067 6933]
# 0.33693285000054085
# 병합 군집의 클러스터 크기: [9994    6]
# 0.8664144195471685
# 병합 군집의 클러스터 크기: [9999    1]
# 0.9074887642792022
# 병합 군집의 클러스터 크기: [9999    1]
# 0.8969411370809672

# %%
#bi_3 scale X
for j in link:
    agg = AgglomerativeClustering(n_clusters=2, linkage =j)
    result = agg.fit_predict(X_train)
    print("병합 군집의 클러스터 크기:",
       np.bincount(result))
    print(printSilhouette(X_train, result))
# Out:
# 병합 군집의 클러스터 크기: [ 302 9698]
# 0.9956218810965849
# 병합 군집의 클러스터 크기: [ 302 9698]
# 0.9956218810965849
# 병합 군집의 클러스터 크기: [ 302 9698]
# 0.9956218810965849
# 병합 군집의 클러스터 크기: [ 302 9698]
# 0.9956218810965849

# %%
#bi_3 scale X
for j in link:
    agg = AgglomerativeClustering(n_clusters=2, linkage =j)
    result = agg.fit_predict(X_train)
    print("병합 군집의 클러스터 크기:",
       np.bincount(result))
    print(printSilhouette(X_train, result))
# Out:
# 병합 군집의 클러스터 크기: [ 302 9698]
# 0.9956218810965849
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-b97477937c7d> in <module>
#       2 for j in link:
#       3     agg = AgglomerativeClustering(n_clusters=2, linkage =j)
# ----> 4     result = agg.fit_predict(X_train)
#       5     print("병합 군집의 클러스터 크기:",
#       6        np.bincount(result))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_predict(self, X, y)
#     353         # non-optimized default implementation; override when a better
#     354         # method is possible for a given clustering algorithm
# --> 355         self.fit(X)
#     356         return self.labels_
#     357
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\hierarchical.py in fit(self, X, y)
#     829             memory.cache(tree_builder)(X, connectivity,
# ...

# %%
X_temp = X_train[:,0:3]
Y_temp = Y_train

# %%
#bi_4 scale O
for j in link:
    agg = AgglomerativeClustering(n_clusters=2, linkage =j)
    result = agg.fit_predict(X_temp)
    print("병합 군집의 클러스터 크기:",
       np.bincount(result))
    print(printSilhouette(X_temp, result))
# Out:
# 병합 군집의 클러스터 크기: [8231 1769]
# 0.6814808478306233
# 병합 군집의 클러스터 크기: [8231 1769]
# 0.6814808478306233
# 병합 군집의 클러스터 크기: [8232 1768]
# 0.6815547095248706
# 병합 군집의 클러스터 크기: [8231 1769]
# 0.6814808478306233

# %%
agg = AgglomerativeClustering(n_clusters=2, linkage ='ward')
result = agg.fit_predict(X_train)

# %%
from scipy.cluster.hierarchy import dendrogram, ward, single, complete, average
# 거리 정보가 담긴 배열을 리턴합니다
linkage_array = average(X_train)
# 클러스터 간의 거리 정보가 담긴 linkage_array를 사용해 덴드로그램을 그립니다
dendrogram(linkage_array)
# Out:
# {'icoord': [[35.0, 35.0, 45.0, 45.0],
#   [25.0, 25.0, 40.0, 40.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [65.0, 65.0, 80.0, 80.0],
#   [55.0, 55.0, 72.5, 72.5],
#   [105.0, 105.0, 115.0, 115.0],
#   [125.0, 125.0, 135.0, 135.0],
#   [110.0, 110.0, 130.0, 130.0],
#   [95.0, 95.0, 120.0, 120.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [165.0, 165.0, 180.0, 180.0],
#   [155.0, 155.0, 172.5, 172.5],
#   [145.0, 145.0, 163.75, 163.75],
#   [195.0, 195.0, 205.0, 205.0],
#   [235.0, 235.0, 245.0, 245.0],
#   [225.0, 225.0, 240.0, 240.0],
#   [215.0, 215.0, 232.5, 232.5],
#   [265.0, 265.0, 275.0, 275.0],
#   [255.0, 255.0, 270.0, 270.0],
#   [223.75, 223.75, 262.5, 262.5],
#   [305.0, 305.0, 315.0, 315.0],
#   [335.0, 335.0, 345.0, 345.0],
#   [325.0, 325.0, 340.0, 340.0],
#   [310.0, 310.0, 332.5, 332.5],
#   [295.0, 295.0, 321.25, 321.25],
#   [285.0, 285.0, 308.125, 308.125],
#   [355.0, 355.0, 365.0, 365.0],
#   [415.0, 415.0, 425.0, 425.0],
#   [405.0, 405.0, 420.0, 420.0],
# ...
